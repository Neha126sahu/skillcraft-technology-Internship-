# %% [markdown]
# ## Task-2 Performing EDA
# #### * Exploring the relationship between variables
# #### * Identifying the patterns & trends of the data¶

# %%
# Importing necessary libraries

import pandas as pd 
import numpy as np 
pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',4000)

# %%
# making a dataframe 

df = pd.read_csv('Movies.csv')

# %%
# checking some records of the dataframe 

df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
# checking the column names 

df.columns.tolist()
# Out:
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
# checking the info 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3853 entries, 0 to 3852
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      3851 non-null   object
#  1   director_name              3853 non-null   object
#  2   num_critic_for_reviews     3852 non-null   float64
#  3   duration                   3852 non-null   float64
#  4   director_facebook_likes    3853 non-null   float64
#  5   actor_3_facebook_likes     3847 non-null   float64
#  6   actor_2_name               3852 non-null   object
#  7   actor_1_facebook_likes     3853 non-null   float64
#  8   gross                      3853 non-null   float64
#  9   genres                     3853 non-null   object
#  10  actor_1_name               3853 non-null   object
#  11  movie_title                3853 non-null   object
#  12  num_voted_users            3853 non-null   int64
# ...

# %%
# checking statistical terms of the dataframe 

df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             3852.000000  3852.000000              3853.000000
# mean               163.046989   109.921080               784.507397
# std                123.927258    22.741728              3027.395958
# min                  1.000000    34.000000                 0.000000
# 25%                 72.000000    95.000000                10.000000
# 50%                134.000000   106.000000                58.000000
# 75%                221.000000   120.000000               222.000000
# max                813.000000   330.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             3847.000000             3853.000000  3.853000e+03
# mean               747.290096             7575.558526  5.096547e+07
# std               1841.623945            15405.383114  6.932033e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
# checking the shape of the dataframe 

df.shape
# Out:
# (3853, 28)

# %%
# checking the missing values in dataframe 

df.isnull().sum()
# Out:
# color                         2
# director_name                 0
# num_critic_for_reviews        1
# duration                      1
# director_facebook_likes       0
# actor_3_facebook_likes        6
# actor_2_name                  1
# actor_1_facebook_likes        0
# gross                         0
# genres                        0
# actor_1_name                  0
# movie_title                   0
# num_voted_users               0
# cast_total_facebook_likes     0
# actor_3_name                  6
# facenumber_in_poster          6
# plot_keywords                30
# movie_imdb_link               0
# num_user_for_reviews          0
# language                      4
# country                       0
# content_rating               48
# budget                        0
# title_year                    0
# actor_2_facebook_likes        1
# imdb_score                    0
# aspect_ratio                 72
# movie_facebook_likes          0
# dtype: int64

# %%
# finding null count 

null_count = df.isnull().sum()/len(df)

# %%
# checking null percentage of each column 

null_perc = pd.DataFrame({ 'column name' : df.columns , 'null perc' : null_count})

# %%
# cross varifying of records 

df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %% [markdown]
# #### Here we can see that we have very less percentage of null value , so it is ok to drop that records

# %%
# dropping the records which have missing values 

df.dropna(axis = 0 , inplace = True)

# %%
# cross verifying the dataframe after dropping the records 

df.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
# Importing necessary libraries for data visualization 

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# plotting a bar plot for column'color'

sns.barplot(df['color'])
plt.show()

# %% [markdown]
#  #### Insights- here we can clearly see that black & white movies have more than color movies , here we can assume that in old times color movies were not invented so that's the reason behind it

# %%
# checking the value counts of column 'language' 

df['language'].value_counts()
# Out:
# language
# English       3566
# French          34
# Spanish         23
# Mandarin        14
# German          10
# Japanese        10
# Cantonese        7
# Italian          7
# Portuguese       5
# Hindi            5
# Korean           5
# Norwegian        4
# Danish           3
# Thai             3
# Persian          3
# Dutch            3
# Indonesian       2
# Dari             2
# Aboriginal       2
# Aramaic          1
# Hungarian        1
# Kazakh           1
# Maya             1
# Filipino         1
# Mongolian        1
# Czech            1
# Russian          1
# Zulu             1
# Hebrew           1
# Arabic           1
# Vietnamese       1
# Bosnian          1
# Romanian         1
# Name: count, dtype: int64

# %% [markdown]
# #### Insights - here we can see that 'english' language is most demanded as compare to other language
# #### We will plot a countplot of the column 'language'

# %%
# plotting a countplot for column'language'

sns.countplot(df['language'])
plt.show()

# %%
# checking the value counts of column 'country' 

df['country'].value_counts()
# Out:
# country
# USA               2960
# UK                 313
# France             101
# Germany             79
# Canada              59
# Australia           39
# Spain               21
# Japan               15
# Hong Kong           13
# China               12
# Italy               11
# New Zealand         11
# South Korea          8
# Denmark              8
# Ireland              7
# Mexico               6
# Brazil               5
# India                5
# Iran                 4
# Thailand             4
# Norway               4
# Russia               3
# Argentina            3
# Netherlands          3
# South Africa         3
# Czech Republic       3
# Hungary              2
# Taiwan               2
# Romania              2
# Finland              1
# Indonesia            1
# Israel               1
# Poland               1
# Colombia             1
# New Line             1
# Iceland              1
# Aruba                1
# Peru                 1
# Belgium              1
# ...

# %% [markdown]
# #### Insights - here we can see that country 'USA' has most no. of movie released in that country
# #### So we will just plot a countplot of it

# %%
# plotting countplot for column 'country'

plt.figure(figsize = (10,10))
sns.countplot(df['country'])
plt.show()

# %%
# plotting a countplot of genres present in the dataframe 

sns.histplot(df['genres'])
plt.show()

# %% [markdown]
# #### As we can't clearly see the genres in plot because we have more genres present in our records so from genres we can't find any insights

# %%
# checking value counts of column 'imdb-score' 

df['imdb_score'].value_counts()
# Out:
# imdb_score
# 6.7    175
# 6.6    161
# 6.5    152
# 6.4    146
# 6.8    142
# 6.1    142
# 7.1    140
# 7.0    138
# 7.2    137
# 6.9    135
# 7.3    135
# 6.2    133
# 6.3    133
# 5.9    124
# 7.6    100
# 6.0     97
# 7.4     97
# 5.8     95
# 7.5     93
# 5.6     92
# 7.7     89
# 5.7     84
# 7.8     82
# 5.5     77
# 5.4     73
# 5.3     69
# 5.1     54
# 8.0     54
# 7.9     51
# 8.1     47
# 5.2     46
# 4.9     37
# 4.8     30
# 5.0     30
# 4.6     29
# 8.3     24
# 8.2     24
# 4.7     20
# 4.4     19
# 4.5     19
# 4.1     18
# 8.5     18
# 4.3     16
# 8.4     14
# 4.2     12
# 3.6      9
# 3.3      9
# 3.8      9
# 3.9      8
# 4.0      8
# 8.6      8
# 3.5      8
# 8.7      7
# 2.8      5
# 3.7      5
# 8.8      5
# 8.9      4
# 2.7      4
# 3.1      3
# 2.1      3
# 3.0      3
# 3.4      3
# 2.3      3
# 1.9      2
# 9.0      2
# 2.4      2
# 2.9      2
# 9.3      1
# 1.6      1
# 2.5      1
# 2.2      1
# 9.2      1
# 2.0      1
# 3.2      1
# ...

# %% [markdown]
# #### As we can see that imdb score has more value counts , so we will plot a histogram

# %%
plt.hist(df['imdb_score'])
plt.show()

# %% [markdown]
# #### Insights- here we get that highest imdb score lies between around 6.5-7

# %%
# checking the value count of the column 'title year'

df['title_year'].value_counts()
# Out:
# title_year
# 2006.0    188
# 2002.0    186
# 2008.0    182
# 2005.0    182
# 2009.0    181
# 2004.0    178
# 2001.0    176
# 2010.0    167
# 2011.0    167
# 2013.0    162
# 2000.0    157
# 1999.0    157
# 2012.0    155
# 2007.0    151
# 2003.0    145
# 2014.0    142
# 2015.0    125
# 1998.0    115
# 1997.0    100
# 1996.0     92
# 1995.0     66
# 2016.0     58
# 1994.0     51
# 1993.0     44
# 1992.0     33
# 1989.0     33
# 1991.0     30
# 1987.0     30
# 1988.0     29
# 1990.0     26
# 1986.0     25
# 1984.0     22
# 1981.0     17
# 1982.0     16
# 1985.0     15
# 1980.0     14
# 1983.0     13
# 1978.0      8
# 1974.0      7
# 1977.0      7
# 1979.0      6
# 1973.0      5
# 1965.0      5
# 1964.0      5
# 1970.0      4
# 1969.0      3
# 1963.0      3
# 1975.0      3
# 1971.0      3
# 1953.0      2
# 1946.0      2
# 1976.0      2
# 1972.0      2
# 1939.0      2
# 1962.0      2
# 1968.0      2
# 1954.0      2
# 1966.0      1
# 1959.0      1
# 1935.0      1
# 1937.0      1
# ...

# %% [markdown]
# #### Here we can see that most demanding year was 2006 so we will plot a graphical representation of it

# %%
sns.histplot(df['title_year'])
plt.show()

# %% [markdown]
# #### Here we can clearly see that most demanding year lies between 2000-2010 somewheer around 2006

# %%
# checking datatype of column 'aspect ratio'

df['aspect_ratio'].dtypes
# Out:
# dtype('float64')

# %%
# checking value count of thre column 'aspect ratio' 

df['aspect_ratio'].value_counts()
# Out:
# aspect_ratio
# 2.35     1968
# 1.85     1577
# 1.37       48
# 1.66       39
# 1.78       34
# 1.33       18
# 2.39       11
# 2.20       10
# 2.00        3
# 2.40        3
# 2.76        3
# 1.75        2
# 1.18        1
# 2.55        1
# 1.77        1
# 1.50        1
# 2.24        1
# 16.00       1
# Name: count, dtype: int64

# %% [markdown]
# #### Here we can see that highest aspect ratio is 2.35 , so we will plot a histogram of it

# %%
plt.figure(figsize = (8,4))
sns.histplot(df['aspect_ratio'])
plt.show()

# %%
# Selecting numerical coulmns for plotting heatmap 

num_cols = df.select_dtypes(include = ('int64','float64'))

# %%
# checking head of the numeric columns

num_cols.head()
# Out:
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
# 3                   813.0     164.0                  22000.0
# 4                   462.0     132.0                    475.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes        gross  \
# 0                   855.0                  1000.0  760505847.0
# 1                  1000.0                 40000.0  309404152.0
# 2                   161.0                 11000.0  200074175.0
# 3                 23000.0                 27000.0  448130642.0
# 4                   530.0                   640.0   73058679.0
#
#    num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# 0           886204                       4834                   0.0
# 1           471220                      48350                   0.0
# ...

# %%
# selecting columns with float datatype 

float_cols  = df.select_dtypes(include = ('float64'))

# %%
# checking those columns 

float_cols.head()
# Out:
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
# 3                   813.0     164.0                  22000.0
# 4                   462.0     132.0                    475.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes        gross  \
# 0                   855.0                  1000.0  760505847.0
# 1                  1000.0                 40000.0  309404152.0
# 2                   161.0                 11000.0  200074175.0
# 3                 23000.0                 27000.0  448130642.0
# 4                   530.0                   640.0   73058679.0
#
#    facenumber_in_poster  num_user_for_reviews       budget  title_year  \
# 0                   0.0                3054.0  237000000.0      2009.0
# 1                   0.0                1238.0  300000000.0      2007.0
# ...

# %%
# for finding correlation between those columns,now making a dataframe from those columns

corr_cols = df[['num_critic_for_reviews','duration','director_facebook_likes','actor_3_facebook_likes','actor_1_facebook_likes','gross','facenumber_in_poster','num_user_for_reviews','budget','title_year','actor_2_facebook_likes']]

# %%
# checking the new dataframe 

corr_cols.head()
# Out:
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
# 3                   813.0     164.0                  22000.0
# 4                   462.0     132.0                    475.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes        gross  \
# 0                   855.0                  1000.0  760505847.0
# 1                  1000.0                 40000.0  309404152.0
# 2                   161.0                 11000.0  200074175.0
# 3                 23000.0                 27000.0  448130642.0
# 4                   530.0                   640.0   73058679.0
#
#    facenumber_in_poster  num_user_for_reviews       budget  title_year  \
# 0                   0.0                3054.0  237000000.0      2009.0
# 1                   0.0                1238.0  300000000.0      2007.0
# ...

# %%
# defining a variable named 'corr' for finding correlation between them 

corr = df[['num_critic_for_reviews','duration','director_facebook_likes','actor_3_facebook_likes','actor_1_facebook_likes','gross','facenumber_in_poster','num_user_for_reviews','budget','title_year','actor_2_facebook_likes']].corr()

# %%
# checking the correlation 

corr
# Out:
#                          num_critic_for_reviews  duration  \
# num_critic_for_reviews                 1.000000  0.227587
# duration                               0.227587  1.000000
# director_facebook_likes                0.175703  0.180386
# actor_3_facebook_likes                 0.245405  0.120741
# actor_1_facebook_likes                 0.165602  0.082857
# gross                                  0.460758  0.242561
# facenumber_in_poster                  -0.035682  0.027459
# num_user_for_reviews                   0.562568  0.352045
# budget                                 0.103903  0.067363
# title_year                             0.420323 -0.131623
# actor_2_facebook_likes                 0.251081  0.126613
#
#                          director_facebook_likes  actor_3_facebook_likes  \
# num_critic_for_reviews                  0.175703                0.245405
# duration                                0.180386                0.120741
# ...

# %%
# plotting heatmap of columns with float datatye 

plt.figure(figsize = (10,4))
sns.heatmap(data = corr , annot = True)
plt.show()
